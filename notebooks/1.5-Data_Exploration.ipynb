# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np
from pathlib import Path
import sys
import torch

# %%
NB_DIR = Path.cwd()
PROJ_ROOT = NB_DIR.parent
DATA_DIR = PROJ_ROOT / 'data' / 'raw'
sys.path.append(str(PROJ_ROOT))

# %%
df = pd.read_csv(DATA_DIR / 'Movie_Ratings.csv', low_memory=False)

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %%
from src.movie_dataset import MovieRatingsDataset

# %%
dataset = MovieRatingsDataset()

# %%
dataset.df.head()

# %%
dataset.df.describe()

# %%
dataset.df.info()

# %%
dataset.df.isnull().sum()

# %%
dataset.df.duplicated().sum()

# %%
user, item, rating = dataset[0]
print(f'User: {user}, Item: {item}, Rating: {rating}')

# %%
from torch.utils.data import DataLoader

# %%
loader = DataLoader(dataset, batch_size=8, shuffle=True)

sample_batch = next(iter(loader))
users, items, ratings = sample_batch
print(f'Users: {users.shape}')
print(f'Items: {items.shape}')
print(f'Ratings: {ratings}')

# %% [markdown]
# ##### Now our data is prepared for training.
