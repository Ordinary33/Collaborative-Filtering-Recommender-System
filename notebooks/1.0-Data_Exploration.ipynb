# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np
from pathlib import Path
import sys
import torch

# %%
NB_DIR = Path.cwd()
PROJ_ROOT = NB_DIR.parent
DATA_DIR = PROJ_ROOT / 'data' / 'raw'
sys.path.append(str(PROJ_ROOT))

# %%
from src.dataset import RatingsDataset
from torch.utils.data import DataLoader

# %%
print(DATA_DIR)

# %%
df = pd.read_csv(DATA_DIR / 'Ratings.csv', low_memory=False)

# %%
df.head()

# %%
df.info()

# %% [markdown]
# ##### We check the encoded data

# %%
dataset = RatingsDataset()

dataset.df.head()

# %%
dataset.df.describe()

# %%
dataset.df.duplicated().sum()

# %% [markdown]
# ##### This confirms our user index and book index have succesfully been encoded from 0 to n-1

# %%
user, item, rating = dataset[0]
print(f'User: {user}, Item: {item}, Rating: {rating}')

# %%
loader = DataLoader(dataset, batch_size=8, shuffle=True)

sample_batch = next(iter(loader))
users, items, ratings = sample_batch
print(f'Users: {users.shape}')
print(f'Items: {items.shape}')
print(f'Ratings: {ratings}')
